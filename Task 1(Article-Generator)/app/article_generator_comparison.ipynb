# %%
import requests
import json

models = ['tinyllama', 'gemma:2b', 'mistral']

prompt = "Write a 200-word article about the importance of clean energy in modern society."

def generate_article(model_name, prompt):
    url = f"http://localhost:11434/api/generate"
    payload = {
        "model": model_name,
        "prompt": prompt,
        "stream": False
    }

    response = requests.post(url, json=payload)
    
    if response.status_code == 200:
        result = response.json()
        return result.get('response', '')
    else:
        return f"Error: {response.status_code} - {response.text}"

results = {}
for model in models:
    print(f"Generating with {model}...")
    article = generate_article(model, prompt)
    results[model] = article

for model, article in results.items():
    print(f"\n--- Article by {model} ---\n")
    print(article)
    print("\n" + "="*80 + "\n")
# Out:
# Generating with tinyllama...
# Generating with gemma:2b...
# Generating with mistral...
#
# --- Article by tinyllama ---
#
# Clean Energy: The Future of Modern Society
#
# As we continue to transition from an oil and coal-based economy towards a more sustainable, renewable future, the importance of clean energy has never been more apparent. With the rapid rise of global temperatures, climate change, and environmental degradation, it is imperative that we implement strategies to address these issues. Clean energy provides one such solution, which can not only help mitigate the impacts of climate change but also significantly reduce energy costs for households and businesses alike. In this article, we will explore the importance of clean energy in modern society, the current state of renewable power production, and potential solutions to address renewable energy challenges.
#
# Clean Energy: The Future of Modern Society
#
# Renewable energy is a key part of the solution to combating climate change. According to the International Renewable Energy Agency (IRENA), wind power accounted for approximately 50% of new installed capacity worldwide in 2019, while solar power accounted for around 38%. These figures demonstrate that renewables are on track to meet or exceed global energy demand growth.
#
# Renewable energy is a sustainable and reliable source of energy that can be generated from sources such as wind, hydroelectricity, solar power, geothermal, and biomass. It produces no greenhouse gas emissions during its generation process, which makes it an ideal solution for reducing carbon footprints, a critical component of the fight against climate change. Additionally, renewable energy can help mitigate environmental degradation by reducing air pollution, improving water quality, and conserving natural resources such as land, water, and forest.
#
# The Current State of Renewable Power Production
#
# Renewables are becoming increasingly cost-competitive with fossil fuels in many parts of the world. According to a report by Bloomberg New Energy Finance, renewable energy is now cheaper than fossil fuels in most of the world's major economies. This is attributed to advancements in technology, policies and incentives that promote the use of renewables.
#
# In North America, the average cost for wind power has fallen by 60% in the past decade, and solar PV costs have dropped by approximately 50%. In Europe, the cost of wind energy has fallen by over 40% over the past five years, making it more competitive with fossil fuels. The International Energy Agency (IEA) estimates that by 2030, renewable energy could provide up to two-thirds of global electricity demand growth.
#
# Potential Solutions to Address Renewable Energy Challenges
#
# Despite the potential benefits of clean energy, there are challenges facing its adoption. One major obstacle is that many countries and regions have yet to establish sufficient infrastructure to support renewable power generation. This includes adequate transmission networks to transport renewables from the place of production to where they are used. Another challenge is the high upfront costs associated with renewable energy projects, including capital expenditure (capex) and operating expenditures (opex).
#
# A solution to this issue is through public-private partnerships between investors, government agencies, and utilities to finance and construct new renewables facilities. This approach has been successful in countries like China, which has invested heavily in solar and wind power, leading to a rapid increase in their share of global energy production.
#
# Another solution is to address the intermittency of renewable energy sources such as wind and solar power. One way to do this is through grid modernization, which involves expanding the capacity of existing grids with additional transmission infrastructure to accommodate the growth of renewables. Another approach would be to integrate storage technologies into the electricity grids, such as batteries or pumped-storage hydroelectric systems, to enable grid stability and reliability.
#
# Conclusion
#
# In conclusion, clean energy is an essential part of the solution to combatting climate change. Renewable power production offers sustainable, reliable, and cost-competitive sources of energy. However, there are still challenges facing its adoption, including high upfront costs, low intermittency, and inadequate infrastructure. As renewable energy is a critical component of the fight against climate change, it's imperative that we implement strategies to address these issues. Public-private partnerships, grid modernization, and storage technologies can help mitigate the challenges and promote the use of clean energy in modern society.
#
# ================================================================================
#
#
# --- Article by gemma:2b ---
#
# **Clean Energy: A Lifeline for Modern Society**
#
# Clean energy plays a crucial role in shaping a sustainable and prosperous future for our planet. As we face environmental challenges such as climate change, air pollution, and deforestation, transitioning to clean energy sources is essential for protecting our environment and preserving the well-being of our communities.
#
# Renewable energy sources, such as solar and wind power, offer sustainable alternatives to traditional fossil fuels. These clean energy technologies generate electricity without emitting harmful pollutants, reducing air pollution and mitigating climate change.
#
# Moreover, clean energy contributes to energy independence and economic growth. By diversifying our energy sources, we reduce reliance on foreign oil, leading to lower energy costs and increased energy security. Additionally, clean energy projects create new jobs and stimulate economic development.
#
# Furthermore, clean energy is essential for achieving a healthy and sustainable future for our children. By protecting the environment, we ensure a healthier planet where they can grow and play, leading to a brighter future for all.
#
# Investing in clean energy is not just an act of environmental responsibility but also an investment in our future. By embracing clean energy, we create a healthier planet, ensure a sustainable future for all, and foster economic growth.
#
# ================================================================================
#
#
# --- Article by mistral ---
#
#  Title: The Imperative of Clean Energy in Modern Society
#
# In the dynamic and interconnected world we inhabit, the role of clean energy has become pivotal. As societal advancements proliferate, so does our demand for energy, making it a critical driving force behind economic growth and development. However, this insatiable appetite for power poses a significant threat to our planet's health.
#
# Fossil fuels, traditionally the backbone of global energy supply, have long been the culprits in exacerbating climate change and environmental degradation. Their combustion contributes to greenhouse gas emissions, leading to increased temperatures and extreme weather events that imperil both human life and ecosystems.
#
# In contrast, clean energy sources such as solar, wind, and hydropower harness nature's infinite resources without the harmful byproducts of fossil fuels. By transitioning toward a clean energy economy, we can mitigate the detrimental effects of carbon emissions on our environment while fostering a sustainable future for generations to come.
#
# Moreover, the widespread adoption of clean energy offers an opportunity to stimulate economic growth. The renewable energy sector has shown remarkable potential in job creation and innovation. According to the International Renewable Energy Agency (IRENA), the clean energy transition could generate up to 28 million new jobs by 2050, providing a sustainable solution to global employment concerns.
#
# As we navigate this delicate balance between progress and preservation, it is imperative that we prioritize the adoption of clean energy solutions. By investing in a greener future, we can not only ensure our planet's survival but also propel humanity towards a prosperous and sustainable tomorrow. The time to act is now—for our sakes and those yet to come.
#
# ================================================================================

# %%
import textstat
import numpy as np
import language_tool_python

keywords = ['clean energy', 'environment', 'sustainability', 'renewable', 'future']

tool = language_tool_python.LanguageTool('en-US')

def score_article(article):
    score = {}

    word_count = len(article.split())
    score['length_score'] = max(0, 1 - abs(200 - word_count) / 200) * 100

    readability = textstat.flesch_reading_ease(article)
    score['readability_score'] = min(max(readability / 100, 0), 1) * 100

    keyword_hits = sum(1 for kw in keywords if kw.lower() in article.lower())
    score['keyword_score'] = (keyword_hits / len(keywords)) * 100

    matches = tool.check(article)
    grammar_errors = len(matches)
    error_penalty = min(grammar_errors / max(word_count, 1), 1)
    score['grammar_score'] = (1 - error_penalty) * 100

    score['total_score'] = np.mean(list(score.values()))
    return score

scores = {}
for model, article in results.items():
    scores[model] = score_article(article)

for model, score in scores.items():
    print(f"Scores for {model}:")
    for k, v in score.items():
        print(f"  {k}: {v:.0f}%")
    print()

best_model = max(scores, key=lambda m: scores[m]['total_score'])
print(f"🏆 Recommended model for article generation: **{best_model}**")
# Out:
# Downloading LanguageTool latest: 100%|██████████| 252M/252M [05:22<00:00, 781kB/s]
# Unzipping C:\Users\manas\AppData\Local\Temp\tmpovjx5h45.zip to C:\Users\manas\.cache\language_tool_python.
# Downloaded https://internal1.languagetool.org/snapshots/LanguageTool-latest-snapshot.zip to C:\Users\manas\.cache\language_tool_python.
# Scores for tinyllama:
#   length_score: 0%
#   readability_score: 18%
#   keyword_score: 80%
#   grammar_score: 100%
#   total_score: 50%
#
# Scores for gemma:2b:
#   length_score: 98%
#   readability_score: 15%
#   keyword_score: 80%
#   grammar_score: 100%
#   total_score: 73%
#
# Scores for mistral:
#   length_score: 66%
#   readability_score: 17%
#   keyword_score: 80%
#   grammar_score: 100%
#   total_score: 66%
#
# 🏆 Recommended model for article generation: **gemma:2b**
